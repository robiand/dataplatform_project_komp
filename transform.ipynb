# %%
import pandas as pd

df = pd.read_csv("data/products_100.csv")

print(df.head(5))
# Out:
#    id       name   price  quantity     category
# 0   1  Product_1  199.90        12     Clothing
# 1   2  Product_2    5.99       200         Food
# 2   3  Product_3   89.00        30  Electronics
# 3   4  Product_4   15.75        60         Home
# 4   5  Product_5  250.00         8  Electronics

# %%
highest_price_df = df.sort_values("price", ascending=False)
print(highest_price_df.head(15))
# Out:
#     id        name  price  quantity     category
# 24  25  Product_25  250.0         8  Electronics
# 34  35  Product_35  250.0         8  Electronics
# 14  15  Product_15  250.0         8  Electronics
# 4    5   Product_5  250.0         8  Electronics
# 74  75  Product_75  250.0         8  Electronics
# 64  65  Product_65  250.0         8  Electronics
# 94  95  Product_95  250.0         8  Electronics
# 84  85  Product_85  250.0         8  Electronics
# 54  55  Product_55  250.0         8  Electronics
# 44  45  Product_45  250.0         8  Electronics
# 20  21  Product_21  199.9        12     Clothing
# 30  31  Product_31  199.9        12     Clothing
# 40  41  Product_41  199.9        12     Clothing
# 50  51  Product_51  199.9        12     Clothing
# 10  11  Product_11  199.9        12     Clothing
